# %% [markdown]
# # Reproduction of results from Millán et al., 2011 (doi: 10.1029/2011JE003874)
#
# This notebook:
# 1. Sets up the disort thermal model
# 2. Produces an isothermal quartz spectrum using the same n,k values as Millán et al.
# 3. Runs thermal model in steady state to compute thermal profiles
# 4. Recompute and plot quartz spectra using thermal gradients.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
import os
from pathlib import Path

# Add parent directory to path for imports
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Import thermal model components
from core.config_manager import ConfigManager, create_default_base_config
from core.thermal_simulation import ThermalSimulator
from modelmain import Simulator
from config import SimulationConfig
from modelmain import fit_blackbody_wn_banded, max_btemp_blackbody

# Import the new radiance processing framework
from radiance_processor import calculate_radiances_from_results, recompute_radiance_with_angles

# Set up plotting style
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 11
plt.rcParams['lines.linewidth'] = 2

print("Imports completed successfully!")
print("✓ New radiance processing framework imported")
# Out:
# Imports completed successfully!
# ✓ New radiance processing framework imported

# %% [markdown]
# ## Create and Load Base Simulation Configuration
#
# Create and load in a default config file.

# %%
# Option 1: Create a new default configuration
config_path = "../configs/base_configs/analysis_template.yaml"

# Create config directory if it doesn't exist
os.makedirs(os.path.dirname(config_path), exist_ok=True)

# Create default configuration for analysis
create_default_base_config(config_path)

# Load the configuration
config_manager = ConfigManager(config_path)

# Create base configuration
base_config = config_manager.create_config()

print(f"Configuration created at: {config_path}")
print(f"Loaded configuration.")
# Out:
# Default configuration saved to: ../configs/base_configs/analysis_template.yaml
# Configuration created at: ../configs/base_configs/analysis_template.yaml
# Loaded configuration.

# %% [markdown]
# ## Run Isothermal Spectrum Simulation

# %%
# Modify base configuration for our analysis
analysis_overrides = {
    'diurnal': False,                       # Steady state simulation
    'sun': False,                           # Include solar heating
    'T_fixed': True,                        # Temperature is fixed, prevents thermal evolution
    'compute_observer_radiance': True,      # Compute radiance outputs. 
    'thermal_evolution_mode': 'two_wave',   #Run thermal evolution later with broadband vis (turned off) and broadband thermal. 
    'output_radiance_mode': 'hybrid',       #Compute spectral radiance in thermal only. 
    'observer_mu': 1.0,                     # Observer zenith angle (0 for nadir)
    'Et': 80000.0,                          # Mean extinction coefficient for 15 µm quartz, calculated from Mie code. 
    'ssalb_therm': 0.77,                     # Single scattering albedo for thermal radiation (average from mie code)
    'g_therm': 0.6,                         # Asymmetry parameter for thermal radiation (average from mie code)
    'R_base': 0.4,                          # Global reflectivity value for substrate     
    'disort_space_temp': 108.,              # Cold shroud temperature
    'k_dust': 4.2e-4,                       # Phonon thermal conductivity of dust (W/m/K)
    'single_layer': True,                   # Use single-layer model
    'dust_thickness': 0.003,                # 3 mm thick sample
    'T_bottom': 500,                        # Sample base fixed at 500 K
    'bottom_bc': 'dirichlet',               # Bottom boundary condition (fixed temperature)
    'fill_frac': 0.63,                      #Fill fraction for particles. 
    'radius': 15.e-6,                       #Particle radius in meters.
    'mie_file_out': '/Users/ryan/Research/RT_models/RT_thermal_model/Optical_props/quartz_spitzer_combined_15um_mie.txt',  # Mie file for output
    'wn_bounds_out': '/Users/ryan/Research/RT_models/RT_thermal_model/Optical_props/quartz_spitzer_wn_bounds.txt'  # Wavenumber bounds for output files
}

# Create configuration with overrides
config1 = config_manager.create_config(analysis_overrides)

print("Running baseline simulation...")
print(f"Configuration: Et={config1.Et}, k_dust={config1.k_dust}, thickness={config1.dust_thickness}m")

# Run simulation
sim1 = Simulator(config1)
T_out1, phi_vis1, phi_therm1, T_surf1, t_out1 = sim1.run()

print(f"Simulation completed! Output shape: {T_out1.shape}")
print(f"Time range: {t_out1[0]:.0f} to {t_out1[-1]:.0f} seconds")
print(f"Surface temperature range: {T_surf1.min():.1f} to {T_surf1.max():.1f} K")
# Out:
# Running baseline simulation...
# Configuration: Et=80000.0, k_dust=0.00042, thickness=0.003m
# Time step: 0.000844 s, Steps per day: 18305058
# Thermal evolution mode: two_wave
# Non-diurnal step 0, time=0.00s
# Simulation completed in 0.00 s
# Simulation completed! Output shape: (114, 1)
# Time range: 0 to 0 seconds
# Surface temperature range: 475.9 to 475.9 K

# %% [markdown]
# ## Plot isothermal spectrum
#
# No temperature gradient, approximate for an ambient lab measurement.

# %%
# Plot isothermal spectrum using the new radiance processing framework
print("Computing radiance using new framework...")
radiance_results1 = calculate_radiances_from_results(sim1)

# Extract results
wn = radiance_results1['wavenumbers']
final_rad = radiance_results1['radiance_thermal'][:, -1]  # [wavelengths] for single observer
ir_cutoff = np.argmin(np.abs(wn - 1500))  # cm^-1, cutoff for IR bands

# Read bin edges from config
wn_bounds = np.sort(np.loadtxt(sim1.cfg.wn_bounds_out))
T_fit, B_fit, btemps, wn_BB = max_btemp_blackbody(sim1, wn_bounds, final_rad)
emiss_spec = final_rad / B_fit

# Normalize emissivity
idx1 = np.argmin(np.abs(wn - 900))
idx2 = np.argmin(np.abs(wn - 1700))
ds_cf_emis = emiss_spec[idx1:idx2+1].max()

plt.figure()
plt.plot(wn[:ir_cutoff], emiss_spec[:ir_cutoff] + 1 - ds_cf_emis, 
         label=f'Isothermal (T_fit={T_fit:.1f}K)', linewidth=2)
plt.xlabel('Wavenumber [cm$^{-1}$]')
plt.ylabel('Emissivity')
plt.title('Isothermal Emissivity Spectrum - Millan et al. 2011 Reproduction\\n(Radiance / Best-fit Blackbody)')
plt.legend()
plt.grid(True)
plt.gca().invert_xaxis()
plt.show()

print(f"✓ Isothermal radiance computed using new framework")
print(f"  Shape: {radiance_results1['radiance_thermal'].shape}")
print(f"  Spectral mode: {radiance_results1['spectral_mode']}")
print(f"  Observer angles: {radiance_results1['observer_angles_deg']}°")
# Out:
# Computing radiance using new framework...
# Auto-detected simulation object, extracting data...
# Computing surface radiances for 1 observers and 1 time points...
#   Observer 1/1 (mu=1.000, angle=0.0°)
# Surface radiance calculation completed.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 12
#      10 # Read bin edges from config
#      11 wn_bounds = np.sort(np.loadtxt(sim1.cfg.wn_bounds_out))
# ---> 12 T_fit, B_fit, btemps, wn_BB = max_btemp_blackbody(sim1, wn_bounds, final_rad)
#      13 emiss_spec = final_rad / B_fit
#      15 # Normalize emissivity
#
# File ~/Research/RT_models/RT_thermal_model/modelmain.py:1443, in max_btemp_blackbody(sim, wn_edges_input, radiance_input, idx, wn_min, wn_max)
#    1440 	brightness_temps[i] = radiance_to_brightness_temp(wn_edges[i], wn_edges[i+1], radiance[i])
#    1442 # Find maximum brightness temperature
# -> 1443 T_max = np.max(brightness_temps[brightness_temps > 0])
#    1445 # Generate Planck blackbody spectrum at maximum temperature
#    1446 B_max = planck_wn_integrated(wn_edges_input, T_max)
#
# File ~/Research/RT_models/pydisort_env/env/lib/python3.13/site-packages/numpy/core/fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)   2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/Research/RT_models/pydisort_env/env/lib/python3.13/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %% [markdown]
# ## Run thermal evolution model for lunar environmental chamber conditions.

# %%
# Allow thermal evolution now. 
analysis_overrides['T_fixed'] = False
analysis_overrides['steady_tol'] = 1.5e-2  # Convergence tolerance for steady state (K)
config2 = config_manager.create_config(analysis_overrides)

# Run simulation
sim2 = Simulator(config2)
T_out2, phi_vis2, phi_therm2, T_surf2, t_out2 = sim2.run()

print(f"Simulation completed! Output shape: {T_out1.shape}")
print(f"Time range: {t_out1[0]:.0f} to {t_out1[-1]:.0f} seconds")
print(f"Surface temperature range: {T_surf1.min():.1f} to {T_surf1.max():.1f} K")
# Out:
# Time step: 0.000844 s, Steps per day: 18305058
# Thermal evolution mode: two_wave
# Output radiance mode: hybrid
# Non-diurnal step 0, time=0.00s
# [Steady-state check] step 200, max |T - T_ext| = 3.808e+00 K
# [Steady-state check] step 400, max |T - T_ext| = 2.642e+00 K
# [Steady-state check] step 600, max |T - T_ext| = 2.106e+00 K
# [Steady-state check] step 800, max |T - T_ext| = 1.673e+00 K
# [Steady-state check] step 1000, max |T - T_ext| = 1.434e+00 K
# Non-diurnal step 1000, time=0.84s
# [Steady-state check] step 1200, max |T - T_ext| = 1.228e+00 K
# [Steady-state check] step 1400, max |T - T_ext| = 1.138e+00 K
# [Steady-state check] step 1600, max |T - T_ext| = 9.720e-01 K
# [Steady-state check] step 1800, max |T - T_ext| = 9.000e-01 K
# [Steady-state check] step 2000, max |T - T_ext| = 8.326e-01 K
# Non-diurnal step 2000, time=1.69s
# [Steady-state check] step 2200, max |T - T_ext| = 7.697e-01 K
# [Steady-state check] step 2400, max |T - T_ext| = 7.111e-01 K
# [Steady-state check] step 2600, max |T - T_ext| = 6.564e-01 K
# [Steady-state check] step 2800, max |T - T_ext| = 6.581e-01 K
# [Steady-state check] step 3000, max |T - T_ext| = 6.076e-01 K
# Non-diurnal step 3000, time=2.53s
# [Steady-state check] step 3200, max |T - T_ext| = 5.604e-01 K
# [Steady-state check] step 3400, max |T - T_ext| = 5.161e-01 K
# [Steady-state check] step 3600, max |T - T_ext| = 5.177e-01 K
# [Steady-state check] step 3800, max |T - T_ext| = 4.768e-01 K
# [Steady-state check] step 4000, max |T - T_ext| = 4.778e-01 K
# Non-diurnal step 4000, time=3.38s
# [Steady-state check] step 4200, max |T - T_ext| = 4.400e-01 K
# [Steady-state check] step 4400, max |T - T_ext| = 4.407e-01 K
# [Steady-state check] step 4600, max |T - T_ext| = 4.056e-01 K
# [Steady-state check] step 4800, max |T - T_ext| = 4.063e-01 K
# [Steady-state check] step 5000, max |T - T_ext| = 3.736e-01 K
# Non-diurnal step 5000, time=4.22s
# [Steady-state check] step 5200, max |T - T_ext| = 3.743e-01 K
# [Steady-state check] step 5400, max |T - T_ext| = 3.438e-01 K
# [Steady-state check] step 5600, max |T - T_ext| = 3.446e-01 K
# [Steady-state check] step 5800, max |T - T_ext| = 3.450e-01 K
# [Steady-state check] step 6000, max |T - T_ext| = 3.169e-01 K
# Non-diurnal step 6000, time=5.06s
# [Steady-state check] step 6200, max |T - T_ext| = 3.175e-01 K
# [Steady-state check] step 6400, max |T - T_ext| = 3.177e-01 K
# [Steady-state check] step 6600, max |T - T_ext| = 2.918e-01 K
# [Steady-state check] step 6800, max |T - T_ext| = 2.923e-01 K
# [Steady-state check] step 7000, max |T - T_ext| = 2.925e-01 K
# Non-diurnal step 7000, time=5.91s
# [Steady-state check] step 7200, max |T - T_ext| = 2.685e-01 K
# [Steady-state check] step 7400, max |T - T_ext| = 2.689e-01 K
# [Steady-state check] step 7600, max |T - T_ext| = 2.692e-01 K
# [Steady-state check] step 7800, max |T - T_ext| = 2.468e-01 K
# [Steady-state check] step 8000, max |T - T_ext| = 2.472e-01 K
# Non-diurnal step 8000, time=6.75s
# [Steady-state check] step 8200, max |T - T_ext| = 2.475e-01 K
# [Steady-state check] step 8400, max |T - T_ext| = 2.477e-01 K
# [Steady-state check] step 8600, max |T - T_ext| = 2.271e-01 K
# [Steady-state check] step 8800, max |T - T_ext| = 2.274e-01 K
# [Steady-state check] step 9000, max |T - T_ext| = 2.277e-01 K
# Non-diurnal step 9000, time=7.60s
# [Steady-state check] step 9200, max |T - T_ext| = 2.278e-01 K
# [Steady-state check] step 9400, max |T - T_ext| = 2.087e-01 K
# [Steady-state check] step 9600, max |T - T_ext| = 2.091e-01 K
# [Steady-state check] step 9800, max |T - T_ext| = 2.093e-01 K
# [Steady-state check] step 10000, max |T - T_ext| = 2.094e-01 K
# Non-diurnal step 10000, time=8.44s
# [Steady-state check] step 10200, max |T - T_ext| = 2.095e-01 K
# [Steady-state check] step 10400, max |T - T_ext| = 1.920e-01 K
# [Steady-state check] step 10600, max |T - T_ext| = 1.923e-01 K
# [Steady-state check] step 10800, max |T - T_ext| = 1.924e-01 K
# [Steady-state check] step 11000, max |T - T_ext| = 1.925e-01 K
# Non-diurnal step 11000, time=9.28s
# [Steady-state check] step 11200, max |T - T_ext| = 1.926e-01 K
# [Steady-state check] step 11400, max |T - T_ext| = 1.765e-01 K
# [Steady-state check] step 11600, max |T - T_ext| = 1.767e-01 K
# [Steady-state check] step 11800, max |T - T_ext| = 1.768e-01 K
# [Steady-state check] step 12000, max |T - T_ext| = 1.769e-01 K
# Non-diurnal step 12000, time=10.13s
# [Steady-state check] step 12200, max |T - T_ext| = 1.769e-01 K
# [Steady-state check] step 12400, max |T - T_ext| = 1.620e-01 K
# [Steady-state check] step 12600, max |T - T_ext| = 1.622e-01 K
# [Steady-state check] step 12800, max |T - T_ext| = 1.624e-01 K
# [Steady-state check] step 13000, max |T - T_ext| = 1.625e-01 K
# Non-diurnal step 13000, time=10.97s
# [Steady-state check] step 13200, max |T - T_ext| = 1.625e-01 K
# [Steady-state check] step 13400, max |T - T_ext| = 1.626e-01 K
# [Steady-state check] step 13600, max |T - T_ext| = 1.488e-01 K
# [Steady-state check] step 13800, max |T - T_ext| = 1.490e-01 K
# [Steady-state check] step 14000, max |T - T_ext| = 1.491e-01 K
# Non-diurnal step 14000, time=11.82s
# [Steady-state check] step 14200, max |T - T_ext| = 1.492e-01 K
# [Steady-state check] step 14400, max |T - T_ext| = 1.493e-01 K
# [Steady-state check] step 14600, max |T - T_ext| = 1.493e-01 K
# [Steady-state check] step 14800, max |T - T_ext| = 1.366e-01 K
# [Steady-state check] step 15000, max |T - T_ext| = 1.367e-01 K
# Non-diurnal step 15000, time=12.66s
# [Steady-state check] step 15200, max |T - T_ext| = 1.369e-01 K
# [Steady-state check] step 15400, max |T - T_ext| = 1.370e-01 K
# [Steady-state check] step 15600, max |T - T_ext| = 1.371e-01 K
# [Steady-state check] step 15800, max |T - T_ext| = 1.371e-01 K
# [Steady-state check] step 16000, max |T - T_ext| = 1.371e-01 K
# Non-diurnal step 16000, time=13.50s
# [Steady-state check] step 16200, max |T - T_ext| = 1.372e-01 K
# [Steady-state check] step 16400, max |T - T_ext| = 1.255e-01 K
# [Steady-state check] step 16600, max |T - T_ext| = 1.256e-01 K
# [Steady-state check] step 16800, max |T - T_ext| = 1.257e-01 K
# [Steady-state check] step 17000, max |T - T_ext| = 1.258e-01 K
# Non-diurnal step 17000, time=14.35s
# [Steady-state check] step 17200, max |T - T_ext| = 1.259e-01 K
# [Steady-state check] step 17400, max |T - T_ext| = 1.259e-01 K
# [Steady-state check] step 17600, max |T - T_ext| = 1.259e-01 K
# [Steady-state check] step 17800, max |T - T_ext| = 1.151e-01 K
# [Steady-state check] step 18000, max |T - T_ext| = 1.152e-01 K
# Non-diurnal step 18000, time=15.19s
# [Steady-state check] step 18200, max |T - T_ext| = 1.153e-01 K
# [Steady-state check] step 18400, max |T - T_ext| = 1.154e-01 K
# [Steady-state check] step 18600, max |T - T_ext| = 1.155e-01 K
# [Steady-state check] step 18800, max |T - T_ext| = 1.155e-01 K
# [Steady-state check] step 19000, max |T - T_ext| = 1.156e-01 K
# Non-diurnal step 19000, time=16.04s
# [Steady-state check] step 19200, max |T - T_ext| = 1.156e-01 K
# [Steady-state check] step 19400, max |T - T_ext| = 1.156e-01 K
# [Steady-state check] step 19600, max |T - T_ext| = 1.057e-01 K
# [Steady-state check] step 19800, max |T - T_ext| = 1.058e-01 K
# [Steady-state check] step 20000, max |T - T_ext| = 1.059e-01 K
# Non-diurnal step 20000, time=16.88s
# [Steady-state check] step 20200, max |T - T_ext| = 1.060e-01 K
# [Steady-state check] step 20400, max |T - T_ext| = 1.060e-01 K
# [Steady-state check] step 20600, max |T - T_ext| = 1.061e-01 K
# [Steady-state check] step 20800, max |T - T_ext| = 1.061e-01 K
# [Steady-state check] step 21000, max |T - T_ext| = 1.061e-01 K
# Non-diurnal step 21000, time=17.72s
# [Steady-state check] step 21200, max |T - T_ext| = 1.061e-01 K
# [Steady-state check] step 21400, max |T - T_ext| = 1.061e-01 K
# [Steady-state check] step 21600, max |T - T_ext| = 9.706e-02 K
# [Steady-state check] step 21800, max |T - T_ext| = 9.714e-02 K
# [Steady-state check] step 22000, max |T - T_ext| = 9.720e-02 K
# Non-diurnal step 22000, time=18.57s
# [Steady-state check] step 22200, max |T - T_ext| = 9.726e-02 K
# [Steady-state check] step 22400, max |T - T_ext| = 9.731e-02 K
# [Steady-state check] step 22600, max |T - T_ext| = 9.735e-02 K
# [Steady-state check] step 22800, max |T - T_ext| = 9.738e-02 K
# [Steady-state check] step 23000, max |T - T_ext| = 9.740e-02 K
# Non-diurnal step 23000, time=19.41s
# [Steady-state check] step 23200, max |T - T_ext| = 9.741e-02 K
# [Steady-state check] step 23400, max |T - T_ext| = 9.742e-02 K
# [Steady-state check] step 23600, max |T - T_ext| = 8.905e-02 K
# [Steady-state check] step 23800, max |T - T_ext| = 8.912e-02 K
# [Steady-state check] step 24000, max |T - T_ext| = 8.917e-02 K
# Non-diurnal step 24000, time=20.26s
# [Steady-state check] step 24200, max |T - T_ext| = 8.923e-02 K
# [Steady-state check] step 24400, max |T - T_ext| = 8.927e-02 K
# [Steady-state check] step 24600, max |T - T_ext| = 8.931e-02 K
# [Steady-state check] step 24800, max |T - T_ext| = 8.934e-02 K
# [Steady-state check] step 25000, max |T - T_ext| = 8.937e-02 K
# Non-diurnal step 25000, time=21.10s
# [Steady-state check] step 25200, max |T - T_ext| = 8.939e-02 K
# [Steady-state check] step 25400, max |T - T_ext| = 8.940e-02 K
# [Steady-state check] step 25600, max |T - T_ext| = 8.941e-02 K
# [Steady-state check] step 25800, max |T - T_ext| = 8.169e-02 K
# [Steady-state check] step 26000, max |T - T_ext| = 8.175e-02 K
# Non-diurnal step 26000, time=21.94s
# [Steady-state check] step 26200, max |T - T_ext| = 8.181e-02 K
# [Steady-state check] step 26400, max |T - T_ext| = 8.185e-02 K
# [Steady-state check] step 26600, max |T - T_ext| = 8.190e-02 K
# [Steady-state check] step 26800, max |T - T_ext| = 8.193e-02 K
# [Steady-state check] step 27000, max |T - T_ext| = 8.196e-02 K
# Non-diurnal step 27000, time=22.79s
# [Steady-state check] step 27200, max |T - T_ext| = 8.199e-02 K
# [Steady-state check] step 27400, max |T - T_ext| = 8.201e-02 K
# [Steady-state check] step 27600, max |T - T_ext| = 8.203e-02 K
# [Steady-state check] step 27800, max |T - T_ext| = 8.204e-02 K
# [Steady-state check] step 28000, max |T - T_ext| = 8.205e-02 K
# Non-diurnal step 28000, time=23.63s
# [Steady-state check] step 28200, max |T - T_ext| = 8.206e-02 K
# [Steady-state check] step 28400, max |T - T_ext| = 7.499e-02 K
# [Steady-state check] step 28600, max |T - T_ext| = 7.504e-02 K
# [Steady-state check] step 28800, max |T - T_ext| = 7.508e-02 K
# [Steady-state check] step 29000, max |T - T_ext| = 7.512e-02 K
# Non-diurnal step 29000, time=24.48s
# [Steady-state check] step 29200, max |T - T_ext| = 7.516e-02 K
# [Steady-state check] step 29400, max |T - T_ext| = 7.519e-02 K
# [Steady-state check] step 29600, max |T - T_ext| = 7.522e-02 K
# [Steady-state check] step 29800, max |T - T_ext| = 7.524e-02 K
# [Steady-state check] step 30000, max |T - T_ext| = 7.526e-02 K
# Non-diurnal step 30000, time=25.32s
# [Steady-state check] step 30200, max |T - T_ext| = 7.527e-02 K
# [Steady-state check] step 30400, max |T - T_ext| = 7.529e-02 K
# [Steady-state check] step 30600, max |T - T_ext| = 7.530e-02 K
# [Steady-state check] step 30800, max |T - T_ext| = 7.530e-02 K
# [Steady-state check] step 31000, max |T - T_ext| = 7.530e-02 K
# Non-diurnal step 31000, time=26.16s
# [Steady-state check] step 31200, max |T - T_ext| = 6.883e-02 K
# [Steady-state check] step 31400, max |T - T_ext| = 6.887e-02 K
# [Steady-state check] step 31600, max |T - T_ext| = 6.890e-02 K
# [Steady-state check] step 31800, max |T - T_ext| = 6.894e-02 K
# [Steady-state check] step 32000, max |T - T_ext| = 6.897e-02 K
# Non-diurnal step 32000, time=27.01s
# [Steady-state check] step 32200, max |T - T_ext| = 6.899e-02 K
# [Steady-state check] step 32400, max |T - T_ext| = 6.902e-02 K
# [Steady-state check] step 32600, max |T - T_ext| = 6.904e-02 K
# [Steady-state check] step 32800, max |T - T_ext| = 6.905e-02 K
# [Steady-state check] step 33000, max |T - T_ext| = 6.907e-02 K
# Non-diurnal step 33000, time=27.85s
# [Steady-state check] step 33200, max |T - T_ext| = 6.908e-02 K
# [Steady-state check] step 33400, max |T - T_ext| = 6.909e-02 K
# [Steady-state check] step 33600, max |T - T_ext| = 6.910e-02 K
# [Steady-state check] step 33800, max |T - T_ext| = 6.910e-02 K
# [Steady-state check] step 34000, max |T - T_ext| = 6.910e-02 K
# Non-diurnal step 34000, time=28.70s
# [Steady-state check] step 34200, max |T - T_ext| = 6.316e-02 K
# [Steady-state check] step 34400, max |T - T_ext| = 6.319e-02 K
# [Steady-state check] step 34600, max |T - T_ext| = 6.322e-02 K
# [Steady-state check] step 34800, max |T - T_ext| = 6.325e-02 K
# [Steady-state check] step 35000, max |T - T_ext| = 6.328e-02 K
# Non-diurnal step 35000, time=29.54s
# [Steady-state check] step 35200, max |T - T_ext| = 6.330e-02 K
# [Steady-state check] step 35400, max |T - T_ext| = 6.332e-02 K
# [Steady-state check] step 35600, max |T - T_ext| = 6.334e-02 K
# [Steady-state check] step 35800, max |T - T_ext| = 6.336e-02 K
# [Steady-state check] step 36000, max |T - T_ext| = 6.337e-02 K
# Non-diurnal step 36000, time=30.39s
# [Steady-state check] step 36200, max |T - T_ext| = 6.339e-02 K
# [Steady-state check] step 36400, max |T - T_ext| = 6.340e-02 K
# [Steady-state check] step 36600, max |T - T_ext| = 6.340e-02 K
# [Steady-state check] step 36800, max |T - T_ext| = 6.341e-02 K
# [Steady-state check] step 37000, max |T - T_ext| = 6.342e-02 K
# Non-diurnal step 37000, time=31.23s
# [Steady-state check] step 37200, max |T - T_ext| = 6.342e-02 K
# [Steady-state check] step 37400, max |T - T_ext| = 5.794e-02 K
# [Steady-state check] step 37600, max |T - T_ext| = 5.797e-02 K
# [Steady-state check] step 37800, max |T - T_ext| = 5.800e-02 K
# [Steady-state check] step 38000, max |T - T_ext| = 5.802e-02 K
# Non-diurnal step 38000, time=32.07s
# [Steady-state check] step 38200, max |T - T_ext| = 5.805e-02 K
# [Steady-state check] step 38400, max |T - T_ext| = 5.807e-02 K
# [Steady-state check] step 38600, max |T - T_ext| = 5.809e-02 K
# [Steady-state check] step 38800, max |T - T_ext| = 5.811e-02 K
# [Steady-state check] step 39000, max |T - T_ext| = 5.813e-02 K
# Non-diurnal step 39000, time=32.92s
# [Steady-state check] step 39200, max |T - T_ext| = 5.814e-02 K
# [Steady-state check] step 39400, max |T - T_ext| = 5.815e-02 K
# [Steady-state check] step 39600, max |T - T_ext| = 5.817e-02 K
# [Steady-state check] step 39800, max |T - T_ext| = 5.818e-02 K
# [Steady-state check] step 40000, max |T - T_ext| = 5.818e-02 K
# Non-diurnal step 40000, time=33.76s
# [Steady-state check] step 40200, max |T - T_ext| = 5.819e-02 K
# [Steady-state check] step 40400, max |T - T_ext| = 5.820e-02 K
# [Steady-state check] step 40600, max |T - T_ext| = 5.820e-02 K
# [Steady-state check] step 40800, max |T - T_ext| = 5.820e-02 K
# [Steady-state check] step 41000, max |T - T_ext| = 5.317e-02 K
# Non-diurnal step 41000, time=34.61s
# [Steady-state check] step 41200, max |T - T_ext| = 5.320e-02 K
# [Steady-state check] step 41400, max |T - T_ext| = 5.322e-02 K
# [Steady-state check] step 41600, max |T - T_ext| = 5.325e-02 K
# [Steady-state check] step 41800, max |T - T_ext| = 5.327e-02 K
# [Steady-state check] step 42000, max |T - T_ext| = 5.329e-02 K
# Non-diurnal step 42000, time=35.45s
# [Steady-state check] step 42200, max |T - T_ext| = 5.330e-02 K
# [Steady-state check] step 42400, max |T - T_ext| = 5.332e-02 K
# [Steady-state check] step 42600, max |T - T_ext| = 5.334e-02 K
# [Steady-state check] step 42800, max |T - T_ext| = 5.335e-02 K
# [Steady-state check] step 43000, max |T - T_ext| = 5.336e-02 K
# Non-diurnal step 43000, time=36.29s
# [Steady-state check] step 43200, max |T - T_ext| = 5.337e-02 K
# [Steady-state check] step 43400, max |T - T_ext| = 5.338e-02 K
# [Steady-state check] step 43600, max |T - T_ext| = 5.339e-02 K
# [Steady-state check] step 43800, max |T - T_ext| = 5.340e-02 K
# [Steady-state check] step 44000, max |T - T_ext| = 5.341e-02 K
# Non-diurnal step 44000, time=37.14s
# [Steady-state check] step 44200, max |T - T_ext| = 5.341e-02 K
# [Steady-state check] step 44400, max |T - T_ext| = 5.341e-02 K
# [Steady-state check] step 44600, max |T - T_ext| = 5.342e-02 K
# [Steady-state check] step 44800, max |T - T_ext| = 5.342e-02 K
# [Steady-state check] step 45000, max |T - T_ext| = 4.881e-02 K
# Non-diurnal step 45000, time=37.98s
# [Steady-state check] step 45200, max |T - T_ext| = 4.883e-02 K
# [Steady-state check] step 45400, max |T - T_ext| = 4.885e-02 K
# [Steady-state check] step 45600, max |T - T_ext| = 4.887e-02 K
# [Steady-state check] step 45800, max |T - T_ext| = 4.889e-02 K
# [Steady-state check] step 46000, max |T - T_ext| = 4.891e-02 K
# Non-diurnal step 46000, time=38.83s
# [Steady-state check] step 46200, max |T - T_ext| = 4.892e-02 K
# [Steady-state check] step 46400, max |T - T_ext| = 4.894e-02 K
# [Steady-state check] step 46600, max |T - T_ext| = 4.895e-02 K
# [Steady-state check] step 46800, max |T - T_ext| = 4.896e-02 K
# [Steady-state check] step 47000, max |T - T_ext| = 4.897e-02 K
# Non-diurnal step 47000, time=39.67s
# [Steady-state check] step 47200, max |T - T_ext| = 4.898e-02 K
# [Steady-state check] step 47400, max |T - T_ext| = 4.899e-02 K
# [Steady-state check] step 47600, max |T - T_ext| = 4.900e-02 K
# [Steady-state check] step 47800, max |T - T_ext| = 4.901e-02 K
# [Steady-state check] step 48000, max |T - T_ext| = 4.902e-02 K
# Non-diurnal step 48000, time=40.51s
# [Steady-state check] step 48200, max |T - T_ext| = 4.902e-02 K
# [Steady-state check] step 48400, max |T - T_ext| = 4.903e-02 K
# [Steady-state check] step 48600, max |T - T_ext| = 4.903e-02 K
# [Steady-state check] step 48800, max |T - T_ext| = 4.903e-02 K
# [Steady-state check] step 49000, max |T - T_ext| = 4.903e-02 K
# Non-diurnal step 49000, time=41.36s
# [Steady-state check] step 49200, max |T - T_ext| = 4.903e-02 K
# [Steady-state check] step 49400, max |T - T_ext| = 4.481e-02 K
# [Steady-state check] step 49600, max |T - T_ext| = 4.483e-02 K
# [Steady-state check] step 49800, max |T - T_ext| = 4.485e-02 K
# [Steady-state check] step 50000, max |T - T_ext| = 4.486e-02 K
# Non-diurnal step 50000, time=42.20s
# [Steady-state check] step 50200, max |T - T_ext| = 4.488e-02 K
# [Steady-state check] step 50400, max |T - T_ext| = 4.489e-02 K
# [Steady-state check] step 50600, max |T - T_ext| = 4.491e-02 K
# [Steady-state check] step 50800, max |T - T_ext| = 4.492e-02 K
# [Steady-state check] step 51000, max |T - T_ext| = 4.493e-02 K
# Non-diurnal step 51000, time=43.05s
# [Steady-state check] step 51200, max |T - T_ext| = 4.494e-02 K
# [Steady-state check] step 51400, max |T - T_ext| = 4.495e-02 K
# [Steady-state check] step 51600, max |T - T_ext| = 4.496e-02 K
# [Steady-state check] step 51800, max |T - T_ext| = 4.497e-02 K
# [Steady-state check] step 52000, max |T - T_ext| = 4.498e-02 K
# Non-diurnal step 52000, time=43.89s
# [Steady-state check] step 52200, max |T - T_ext| = 4.498e-02 K
# [Steady-state check] step 52400, max |T - T_ext| = 4.499e-02 K
# [Steady-state check] step 52600, max |T - T_ext| = 4.500e-02 K
# [Steady-state check] step 52800, max |T - T_ext| = 4.500e-02 K
# [Steady-state check] step 53000, max |T - T_ext| = 4.501e-02 K
# Non-diurnal step 53000, time=44.73s
# [Steady-state check] step 53200, max |T - T_ext| = 4.501e-02 K
# [Steady-state check] step 53400, max |T - T_ext| = 4.501e-02 K
# [Steady-state check] step 53600, max |T - T_ext| = 4.501e-02 K
# [Steady-state check] step 53800, max |T - T_ext| = 4.502e-02 K
# [Steady-state check] step 54000, max |T - T_ext| = 4.502e-02 K
# Non-diurnal step 54000, time=45.58s
# [Steady-state check] step 54200, max |T - T_ext| = 4.115e-02 K
# [Steady-state check] step 54400, max |T - T_ext| = 4.116e-02 K
# [Steady-state check] step 54600, max |T - T_ext| = 4.118e-02 K
# [Steady-state check] step 54800, max |T - T_ext| = 4.119e-02 K
# [Steady-state check] step 55000, max |T - T_ext| = 4.120e-02 K
# Non-diurnal step 55000, time=46.42s
# [Steady-state check] step 55200, max |T - T_ext| = 4.122e-02 K
# [Steady-state check] step 55400, max |T - T_ext| = 4.123e-02 K
# [Steady-state check] step 55600, max |T - T_ext| = 4.124e-02 K
# [Steady-state check] step 55800, max |T - T_ext| = 4.125e-02 K
# [Steady-state check] step 56000, max |T - T_ext| = 4.126e-02 K
# Non-diurnal step 56000, time=47.27s
# [Steady-state check] step 56200, max |T - T_ext| = 4.127e-02 K
# [Steady-state check] step 56400, max |T - T_ext| = 4.128e-02 K
# [Steady-state check] step 56600, max |T - T_ext| = 4.128e-02 K
# [Steady-state check] step 56800, max |T - T_ext| = 4.129e-02 K
# [Steady-state check] step 57000, max |T - T_ext| = 4.130e-02 K
# Non-diurnal step 57000, time=48.11s
# [Steady-state check] step 57200, max |T - T_ext| = 4.130e-02 K
# [Steady-state check] step 57400, max |T - T_ext| = 4.131e-02 K
# [Steady-state check] step 57600, max |T - T_ext| = 4.131e-02 K
# [Steady-state check] step 57800, max |T - T_ext| = 4.132e-02 K
# [Steady-state check] step 58000, max |T - T_ext| = 4.132e-02 K
# Non-diurnal step 58000, time=48.95s
# [Steady-state check] step 58200, max |T - T_ext| = 4.132e-02 K
# [Steady-state check] step 58400, max |T - T_ext| = 4.133e-02 K
# [Steady-state check] step 58600, max |T - T_ext| = 4.133e-02 K
# [Steady-state check] step 58800, max |T - T_ext| = 4.133e-02 K
# [Steady-state check] step 59000, max |T - T_ext| = 4.133e-02 K
# Non-diurnal step 59000, time=49.80s
# [Steady-state check] step 59200, max |T - T_ext| = 4.133e-02 K
# [Steady-state check] step 59400, max |T - T_ext| = 3.779e-02 K
# [Steady-state check] step 59600, max |T - T_ext| = 3.780e-02 K
# [Steady-state check] step 59800, max |T - T_ext| = 3.781e-02 K
# [Steady-state check] step 60000, max |T - T_ext| = 3.782e-02 K
# Non-diurnal step 60000, time=50.64s
# [Steady-state check] step 60200, max |T - T_ext| = 3.783e-02 K
# [Steady-state check] step 60400, max |T - T_ext| = 3.784e-02 K
# [Steady-state check] step 60600, max |T - T_ext| = 3.785e-02 K
# [Steady-state check] step 60800, max |T - T_ext| = 3.786e-02 K
# [Steady-state check] step 61000, max |T - T_ext| = 3.787e-02 K
# Non-diurnal step 61000, time=51.49s
# [Steady-state check] step 61200, max |T - T_ext| = 3.788e-02 K
# [Steady-state check] step 61400, max |T - T_ext| = 3.789e-02 K
# [Steady-state check] step 61600, max |T - T_ext| = 3.790e-02 K
# [Steady-state check] step 61800, max |T - T_ext| = 3.790e-02 K
# [Steady-state check] step 62000, max |T - T_ext| = 3.791e-02 K
# Non-diurnal step 62000, time=52.33s
# [Steady-state check] step 62200, max |T - T_ext| = 3.792e-02 K
# [Steady-state check] step 62400, max |T - T_ext| = 3.792e-02 K
# [Steady-state check] step 62600, max |T - T_ext| = 3.793e-02 K
# [Steady-state check] step 62800, max |T - T_ext| = 3.793e-02 K
# [Steady-state check] step 63000, max |T - T_ext| = 3.794e-02 K
# Non-diurnal step 63000, time=53.17s
# [Steady-state check] step 63200, max |T - T_ext| = 3.794e-02 K
# [Steady-state check] step 63400, max |T - T_ext| = 3.795e-02 K
# [Steady-state check] step 63600, max |T - T_ext| = 3.795e-02 K
# [Steady-state check] step 63800, max |T - T_ext| = 3.795e-02 K
# [Steady-state check] step 64000, max |T - T_ext| = 3.795e-02 K
# Non-diurnal step 64000, time=54.02s
# [Steady-state check] step 64200, max |T - T_ext| = 3.796e-02 K
# [Steady-state check] step 64400, max |T - T_ext| = 3.796e-02 K
# [Steady-state check] step 64600, max |T - T_ext| = 3.796e-02 K
# [Steady-state check] step 64800, max |T - T_ext| = 3.796e-02 K
# [Steady-state check] step 65000, max |T - T_ext| = 3.796e-02 K
# Non-diurnal step 65000, time=54.86s
# [Steady-state check] step 65200, max |T - T_ext| = 3.471e-02 K
# [Steady-state check] step 65400, max |T - T_ext| = 3.472e-02 K
# [Steady-state check] step 65600, max |T - T_ext| = 3.473e-02 K
# [Steady-state check] step 65800, max |T - T_ext| = 3.474e-02 K
# [Steady-state check] step 66000, max |T - T_ext| = 3.475e-02 K
# Non-diurnal step 66000, time=55.71s
# [Steady-state check] step 66200, max |T - T_ext| = 3.476e-02 K
# [Steady-state check] step 66400, max |T - T_ext| = 3.477e-02 K
# [Steady-state check] step 66600, max |T - T_ext| = 3.478e-02 K
# [Steady-state check] step 66800, max |T - T_ext| = 3.479e-02 K
# [Steady-state check] step 67000, max |T - T_ext| = 3.479e-02 K
# Non-diurnal step 67000, time=56.55s
# [Steady-state check] step 67200, max |T - T_ext| = 3.480e-02 K
# [Steady-state check] step 67400, max |T - T_ext| = 3.481e-02 K
# [Steady-state check] step 67600, max |T - T_ext| = 3.481e-02 K
# [Steady-state check] step 67800, max |T - T_ext| = 3.482e-02 K
# [Steady-state check] step 68000, max |T - T_ext| = 3.482e-02 K
# Non-diurnal step 68000, time=57.39s
# [Steady-state check] step 68200, max |T - T_ext| = 3.483e-02 K
# [Steady-state check] step 68400, max |T - T_ext| = 3.483e-02 K
# [Steady-state check] step 68600, max |T - T_ext| = 3.484e-02 K
# [Steady-state check] step 68800, max |T - T_ext| = 3.484e-02 K
# [Steady-state check] step 69000, max |T - T_ext| = 3.485e-02 K
# Non-diurnal step 69000, time=58.24s
# [Steady-state check] step 69200, max |T - T_ext| = 3.485e-02 K
# [Steady-state check] step 69400, max |T - T_ext| = 3.485e-02 K
# [Steady-state check] step 69600, max |T - T_ext| = 3.486e-02 K
# [Steady-state check] step 69800, max |T - T_ext| = 3.486e-02 K
# [Steady-state check] step 70000, max |T - T_ext| = 3.486e-02 K
# Non-diurnal step 70000, time=59.08s
# [Steady-state check] step 70200, max |T - T_ext| = 3.486e-02 K
# [Steady-state check] step 70400, max |T - T_ext| = 3.487e-02 K
# [Steady-state check] step 70600, max |T - T_ext| = 3.487e-02 K
# [Steady-state check] step 70800, max |T - T_ext| = 3.487e-02 K
# [Steady-state check] step 71000, max |T - T_ext| = 3.487e-02 K
# Non-diurnal step 71000, time=59.93s
# [Steady-state check] step 71200, max |T - T_ext| = 3.487e-02 K
# [Steady-state check] step 71400, max |T - T_ext| = 3.487e-02 K
# [Steady-state check] step 71600, max |T - T_ext| = 3.190e-02 K
# [Steady-state check] step 71800, max |T - T_ext| = 3.191e-02 K
# [Steady-state check] step 72000, max |T - T_ext| = 3.192e-02 K
# Non-diurnal step 72000, time=60.77s
# [Steady-state check] step 72200, max |T - T_ext| = 3.193e-02 K
# [Steady-state check] step 72400, max |T - T_ext| = 3.193e-02 K
# [Steady-state check] step 72600, max |T - T_ext| = 3.194e-02 K
# [Steady-state check] step 72800, max |T - T_ext| = 3.195e-02 K
# [Steady-state check] step 73000, max |T - T_ext| = 3.196e-02 K
# Non-diurnal step 73000, time=61.61s
# [Steady-state check] step 73200, max |T - T_ext| = 3.196e-02 K
# [Steady-state check] step 73400, max |T - T_ext| = 3.197e-02 K
# [Steady-state check] step 73600, max |T - T_ext| = 3.197e-02 K
# [Steady-state check] step 73800, max |T - T_ext| = 3.198e-02 K
# [Steady-state check] step 74000, max |T - T_ext| = 3.198e-02 K
# Non-diurnal step 74000, time=62.46s
# [Steady-state check] step 74200, max |T - T_ext| = 3.199e-02 K
# [Steady-state check] step 74400, max |T - T_ext| = 3.199e-02 K
# [Steady-state check] step 74600, max |T - T_ext| = 3.200e-02 K
# [Steady-state check] step 74800, max |T - T_ext| = 3.200e-02 K
# [Steady-state check] step 75000, max |T - T_ext| = 3.201e-02 K
# Non-diurnal step 75000, time=63.30s
# [Steady-state check] step 75200, max |T - T_ext| = 3.201e-02 K
# [Steady-state check] step 75400, max |T - T_ext| = 3.201e-02 K
# [Steady-state check] step 75600, max |T - T_ext| = 3.202e-02 K
# [Steady-state check] step 75800, max |T - T_ext| = 3.202e-02 K
# [Steady-state check] step 76000, max |T - T_ext| = 3.202e-02 K
# Non-diurnal step 76000, time=64.15s
# [Steady-state check] step 76200, max |T - T_ext| = 3.203e-02 K
# [Steady-state check] step 76400, max |T - T_ext| = 3.203e-02 K
# [Steady-state check] step 76600, max |T - T_ext| = 3.203e-02 K
# [Steady-state check] step 76800, max |T - T_ext| = 3.203e-02 K
# [Steady-state check] step 77000, max |T - T_ext| = 3.203e-02 K
# Non-diurnal step 77000, time=64.99s
# [Steady-state check] step 77200, max |T - T_ext| = 3.204e-02 K
# [Steady-state check] step 77400, max |T - T_ext| = 3.204e-02 K
# [Steady-state check] step 77600, max |T - T_ext| = 3.204e-02 K
# [Steady-state check] step 77800, max |T - T_ext| = 3.204e-02 K
# [Steady-state check] step 78000, max |T - T_ext| = 3.204e-02 K
# Non-diurnal step 78000, time=65.83s
# [Steady-state check] step 78200, max |T - T_ext| = 3.204e-02 K
# [Steady-state check] step 78400, max |T - T_ext| = 2.932e-02 K
# [Steady-state check] step 78600, max |T - T_ext| = 2.932e-02 K
# [Steady-state check] step 78800, max |T - T_ext| = 2.933e-02 K
# [Steady-state check] step 79000, max |T - T_ext| = 2.934e-02 K
# Non-diurnal step 79000, time=66.68s
# [Steady-state check] step 79200, max |T - T_ext| = 2.935e-02 K
# [Steady-state check] step 79400, max |T - T_ext| = 2.935e-02 K
# [Steady-state check] step 79600, max |T - T_ext| = 2.936e-02 K
# [Steady-state check] step 79800, max |T - T_ext| = 2.936e-02 K
# [Steady-state check] step 80000, max |T - T_ext| = 2.937e-02 K
# Non-diurnal step 80000, time=67.52s
# [Steady-state check] step 80200, max |T - T_ext| = 2.937e-02 K
# [Steady-state check] step 80400, max |T - T_ext| = 2.938e-02 K
# [Steady-state check] step 80600, max |T - T_ext| = 2.938e-02 K
# [Steady-state check] step 80800, max |T - T_ext| = 2.939e-02 K
# [Steady-state check] step 81000, max |T - T_ext| = 2.939e-02 K
# Non-diurnal step 81000, time=68.37s
# [Steady-state check] step 81200, max |T - T_ext| = 2.940e-02 K
# [Steady-state check] step 81400, max |T - T_ext| = 2.940e-02 K
# [Steady-state check] step 81600, max |T - T_ext| = 2.941e-02 K
# [Steady-state check] step 81800, max |T - T_ext| = 2.941e-02 K
# [Steady-state check] step 82000, max |T - T_ext| = 2.941e-02 K
# Non-diurnal step 82000, time=69.21s
# [Steady-state check] step 82200, max |T - T_ext| = 2.942e-02 K
# [Steady-state check] step 82400, max |T - T_ext| = 2.942e-02 K
# [Steady-state check] step 82600, max |T - T_ext| = 2.942e-02 K
# [Steady-state check] step 82800, max |T - T_ext| = 2.943e-02 K
# [Steady-state check] step 83000, max |T - T_ext| = 2.943e-02 K
# Non-diurnal step 83000, time=70.05s
# [Steady-state check] step 83200, max |T - T_ext| = 2.943e-02 K
# [Steady-state check] step 83400, max |T - T_ext| = 2.943e-02 K
# [Steady-state check] step 83600, max |T - T_ext| = 2.944e-02 K
# [Steady-state check] step 83800, max |T - T_ext| = 2.944e-02 K
# [Steady-state check] step 84000, max |T - T_ext| = 2.944e-02 K
# Non-diurnal step 84000, time=70.90s
# [Steady-state check] step 84200, max |T - T_ext| = 2.944e-02 K
# [Steady-state check] step 84400, max |T - T_ext| = 2.944e-02 K
# [Steady-state check] step 84600, max |T - T_ext| = 2.944e-02 K
# [Steady-state check] step 84800, max |T - T_ext| = 2.944e-02 K
# [Steady-state check] step 85000, max |T - T_ext| = 2.944e-02 K
# Non-diurnal step 85000, time=71.74s
# [Steady-state check] step 85200, max |T - T_ext| = 2.945e-02 K
# [Steady-state check] step 85400, max |T - T_ext| = 2.945e-02 K
# [Steady-state check] step 85600, max |T - T_ext| = 2.945e-02 K
# [Steady-state check] step 85800, max |T - T_ext| = 2.945e-02 K
# [Steady-state check] step 86000, max |T - T_ext| = 2.696e-02 K
# Non-diurnal step 86000, time=72.59s
# [Steady-state check] step 86200, max |T - T_ext| = 2.696e-02 K
# [Steady-state check] step 86400, max |T - T_ext| = 2.697e-02 K
# [Steady-state check] step 86600, max |T - T_ext| = 2.697e-02 K
# [Steady-state check] step 86800, max |T - T_ext| = 2.698e-02 K
# [Steady-state check] step 87000, max |T - T_ext| = 2.699e-02 K
# Non-diurnal step 87000, time=73.43s
# [Steady-state check] step 87200, max |T - T_ext| = 2.699e-02 K
# [Steady-state check] step 87400, max |T - T_ext| = 2.700e-02 K
# [Steady-state check] step 87600, max |T - T_ext| = 2.700e-02 K
# [Steady-state check] step 87800, max |T - T_ext| = 2.701e-02 K
# [Steady-state check] step 88000, max |T - T_ext| = 2.701e-02 K
# Non-diurnal step 88000, time=74.27s
# [Steady-state check] step 88200, max |T - T_ext| = 2.701e-02 K
# [Steady-state check] step 88400, max |T - T_ext| = 2.702e-02 K
# [Steady-state check] step 88600, max |T - T_ext| = 2.702e-02 K
# [Steady-state check] step 88800, max |T - T_ext| = 2.703e-02 K
# [Steady-state check] step 89000, max |T - T_ext| = 2.703e-02 K
# Non-diurnal step 89000, time=75.12s
# [Steady-state check] step 89200, max |T - T_ext| = 2.703e-02 K
# [Steady-state check] step 89400, max |T - T_ext| = 2.704e-02 K
# [Steady-state check] step 89600, max |T - T_ext| = 2.704e-02 K
# [Steady-state check] step 89800, max |T - T_ext| = 2.704e-02 K
# [Steady-state check] step 90000, max |T - T_ext| = 2.705e-02 K
# Non-diurnal step 90000, time=75.96s
# [Steady-state check] step 90200, max |T - T_ext| = 2.705e-02 K
# [Steady-state check] step 90400, max |T - T_ext| = 2.705e-02 K
# [Steady-state check] step 90600, max |T - T_ext| = 2.705e-02 K
# [Steady-state check] step 90800, max |T - T_ext| = 2.706e-02 K
# [Steady-state check] step 91000, max |T - T_ext| = 2.706e-02 K
# Non-diurnal step 91000, time=76.81s
# [Steady-state check] step 91200, max |T - T_ext| = 2.706e-02 K
# [Steady-state check] step 91400, max |T - T_ext| = 2.706e-02 K
# [Steady-state check] step 91600, max |T - T_ext| = 2.706e-02 K
# [Steady-state check] step 91800, max |T - T_ext| = 2.706e-02 K
# [Steady-state check] step 92000, max |T - T_ext| = 2.707e-02 K
# Non-diurnal step 92000, time=77.65s
# [Steady-state check] step 92200, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 92400, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 92600, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 92800, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 93000, max |T - T_ext| = 2.707e-02 K
# Non-diurnal step 93000, time=78.49s
# [Steady-state check] step 93200, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 93400, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 93600, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 93800, max |T - T_ext| = 2.707e-02 K
# [Steady-state check] step 94000, max |T - T_ext| = 2.707e-02 K
# Non-diurnal step 94000, time=79.34s
# [Steady-state check] step 94200, max |T - T_ext| = 2.479e-02 K
# [Steady-state check] step 94400, max |T - T_ext| = 2.480e-02 K
# [Steady-state check] step 94600, max |T - T_ext| = 2.480e-02 K
# [Steady-state check] step 94800, max |T - T_ext| = 2.481e-02 K
# [Steady-state check] step 95000, max |T - T_ext| = 2.481e-02 K
# Non-diurnal step 95000, time=80.18s
# [Steady-state check] step 95200, max |T - T_ext| = 2.482e-02 K
# [Steady-state check] step 95400, max |T - T_ext| = 2.482e-02 K
# [Steady-state check] step 95600, max |T - T_ext| = 2.483e-02 K
# [Steady-state check] step 95800, max |T - T_ext| = 2.483e-02 K
# [Steady-state check] step 96000, max |T - T_ext| = 2.483e-02 K
# Non-diurnal step 96000, time=81.03s
# [Steady-state check] step 96200, max |T - T_ext| = 2.484e-02 K
# [Steady-state check] step 96400, max |T - T_ext| = 2.484e-02 K
# [Steady-state check] step 96600, max |T - T_ext| = 2.484e-02 K
# [Steady-state check] step 96800, max |T - T_ext| = 2.485e-02 K
# [Steady-state check] step 97000, max |T - T_ext| = 2.485e-02 K
# Non-diurnal step 97000, time=81.87s
# [Steady-state check] step 97200, max |T - T_ext| = 2.485e-02 K
# [Steady-state check] step 97400, max |T - T_ext| = 2.486e-02 K
# [Steady-state check] step 97600, max |T - T_ext| = 2.486e-02 K
# [Steady-state check] step 97800, max |T - T_ext| = 2.486e-02 K
# [Steady-state check] step 98000, max |T - T_ext| = 2.487e-02 K
# Non-diurnal step 98000, time=82.71s
# [Steady-state check] step 98200, max |T - T_ext| = 2.487e-02 K
# [Steady-state check] step 98400, max |T - T_ext| = 2.487e-02 K
# [Steady-state check] step 98600, max |T - T_ext| = 2.487e-02 K
# [Steady-state check] step 98800, max |T - T_ext| = 2.488e-02 K
# [Steady-state check] step 99000, max |T - T_ext| = 2.488e-02 K
# Non-diurnal step 99000, time=83.56s
# [Steady-state check] step 99200, max |T - T_ext| = 2.488e-02 K
# [Steady-state check] step 99400, max |T - T_ext| = 2.488e-02 K
# [Steady-state check] step 99600, max |T - T_ext| = 2.488e-02 K
# [Steady-state check] step 99800, max |T - T_ext| = 2.489e-02 K
# [Steady-state check] step 100000, max |T - T_ext| = 2.489e-02 K
# Non-diurnal step 100000, time=84.40s
# [Steady-state check] step 100200, max |T - T_ext| = 2.489e-02 K
# [Steady-state check] step 100400, max |T - T_ext| = 2.489e-02 K
# [Steady-state check] step 100600, max |T - T_ext| = 2.489e-02 K
# [Steady-state check] step 100800, max |T - T_ext| = 2.489e-02 K
# [Steady-state check] step 101000, max |T - T_ext| = 2.489e-02 K
# Non-diurnal step 101000, time=85.25s
# [Steady-state check] step 101200, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 101400, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 101600, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 101800, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 102000, max |T - T_ext| = 2.490e-02 K
# Non-diurnal step 102000, time=86.09s
# [Steady-state check] step 102200, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 102400, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 102600, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 102800, max |T - T_ext| = 2.490e-02 K
# [Steady-state check] step 103000, max |T - T_ext| = 2.281e-02 K
# Non-diurnal step 103000, time=86.93s
# [Steady-state check] step 103200, max |T - T_ext| = 2.281e-02 K
# [Steady-state check] step 103400, max |T - T_ext| = 2.282e-02 K
# [Steady-state check] step 103600, max |T - T_ext| = 2.282e-02 K
# [Steady-state check] step 103800, max |T - T_ext| = 2.282e-02 K
# [Steady-state check] step 104000, max |T - T_ext| = 2.283e-02 K
# Non-diurnal step 104000, time=87.78s
# [Steady-state check] step 104200, max |T - T_ext| = 2.283e-02 K
# [Steady-state check] step 104400, max |T - T_ext| = 2.284e-02 K
# [Steady-state check] step 104600, max |T - T_ext| = 2.284e-02 K
# [Steady-state check] step 104800, max |T - T_ext| = 2.284e-02 K
# [Steady-state check] step 105000, max |T - T_ext| = 2.285e-02 K
# Non-diurnal step 105000, time=88.62s
# [Steady-state check] step 105200, max |T - T_ext| = 2.285e-02 K
# [Steady-state check] step 105400, max |T - T_ext| = 2.285e-02 K
# [Steady-state check] step 105600, max |T - T_ext| = 2.286e-02 K
# [Steady-state check] step 105800, max |T - T_ext| = 2.286e-02 K
# [Steady-state check] step 106000, max |T - T_ext| = 2.286e-02 K
# Non-diurnal step 106000, time=89.47s
# [Steady-state check] step 106200, max |T - T_ext| = 2.287e-02 K
# [Steady-state check] step 106400, max |T - T_ext| = 2.287e-02 K
# [Steady-state check] step 106600, max |T - T_ext| = 2.287e-02 K
# [Steady-state check] step 106800, max |T - T_ext| = 2.287e-02 K
# [Steady-state check] step 107000, max |T - T_ext| = 2.288e-02 K
# Non-diurnal step 107000, time=90.31s
# [Steady-state check] step 107200, max |T - T_ext| = 2.288e-02 K
# [Steady-state check] step 107400, max |T - T_ext| = 2.288e-02 K
# [Steady-state check] step 107600, max |T - T_ext| = 2.288e-02 K
# [Steady-state check] step 107800, max |T - T_ext| = 2.288e-02 K
# [Steady-state check] step 108000, max |T - T_ext| = 2.289e-02 K
# Non-diurnal step 108000, time=91.16s
# [Steady-state check] step 108200, max |T - T_ext| = 2.289e-02 K
# [Steady-state check] step 108400, max |T - T_ext| = 2.289e-02 K
# [Steady-state check] step 108600, max |T - T_ext| = 2.289e-02 K
# [Steady-state check] step 108800, max |T - T_ext| = 2.289e-02 K
# [Steady-state check] step 109000, max |T - T_ext| = 2.290e-02 K
# Non-diurnal step 109000, time=92.00s
# [Steady-state check] step 109200, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 109400, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 109600, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 109800, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 110000, max |T - T_ext| = 2.290e-02 K
# Non-diurnal step 110000, time=92.84s
# [Steady-state check] step 110200, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 110400, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 110600, max |T - T_ext| = 2.290e-02 K
# [Steady-state check] step 110800, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 111000, max |T - T_ext| = 2.291e-02 K
# Non-diurnal step 111000, time=93.69s
# [Steady-state check] step 111200, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 111400, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 111600, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 111800, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 112000, max |T - T_ext| = 2.291e-02 K
# Non-diurnal step 112000, time=94.53s
# [Steady-state check] step 112200, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 112400, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 112600, max |T - T_ext| = 2.291e-02 K
# [Steady-state check] step 112800, max |T - T_ext| = 2.100e-02 K
# [Steady-state check] step 113000, max |T - T_ext| = 2.100e-02 K
# Non-diurnal step 113000, time=95.38s
# [Steady-state check] step 113200, max |T - T_ext| = 2.100e-02 K
# [Steady-state check] step 113400, max |T - T_ext| = 2.101e-02 K
# [Steady-state check] step 113600, max |T - T_ext| = 2.101e-02 K
# [Steady-state check] step 113800, max |T - T_ext| = 2.101e-02 K
# [Steady-state check] step 114000, max |T - T_ext| = 2.102e-02 K
# Non-diurnal step 114000, time=96.22s
# [Steady-state check] step 114200, max |T - T_ext| = 2.102e-02 K
# [Steady-state check] step 114400, max |T - T_ext| = 2.102e-02 K
# [Steady-state check] step 114600, max |T - T_ext| = 2.102e-02 K
# [Steady-state check] step 114800, max |T - T_ext| = 2.103e-02 K
# [Steady-state check] step 115000, max |T - T_ext| = 2.103e-02 K
# Non-diurnal step 115000, time=97.06s
# [Steady-state check] step 115200, max |T - T_ext| = 2.103e-02 K
# [Steady-state check] step 115400, max |T - T_ext| = 2.104e-02 K
# [Steady-state check] step 115600, max |T - T_ext| = 2.104e-02 K
# [Steady-state check] step 115800, max |T - T_ext| = 2.104e-02 K
# [Steady-state check] step 116000, max |T - T_ext| = 2.104e-02 K
# Non-diurnal step 116000, time=97.91s
# [Steady-state check] step 116200, max |T - T_ext| = 2.105e-02 K
# [Steady-state check] step 116400, max |T - T_ext| = 2.105e-02 K
# [Steady-state check] step 116600, max |T - T_ext| = 2.105e-02 K
# [Steady-state check] step 116800, max |T - T_ext| = 2.105e-02 K
# [Steady-state check] step 117000, max |T - T_ext| = 2.105e-02 K
# Non-diurnal step 117000, time=98.75s
# [Steady-state check] step 117200, max |T - T_ext| = 2.106e-02 K
# [Steady-state check] step 117400, max |T - T_ext| = 2.106e-02 K
# [Steady-state check] step 117600, max |T - T_ext| = 2.106e-02 K
# [Steady-state check] step 117800, max |T - T_ext| = 2.106e-02 K
# [Steady-state check] step 118000, max |T - T_ext| = 2.106e-02 K
# Non-diurnal step 118000, time=99.60s
# [Steady-state check] step 118200, max |T - T_ext| = 2.107e-02 K
# [Steady-state check] step 118400, max |T - T_ext| = 2.107e-02 K
# [Steady-state check] step 118600, max |T - T_ext| = 2.107e-02 K
# [Steady-state check] step 118800, max |T - T_ext| = 2.107e-02 K
# [Steady-state check] step 119000, max |T - T_ext| = 2.107e-02 K
# Non-diurnal step 119000, time=100.44s
# [Steady-state check] step 119200, max |T - T_ext| = 2.107e-02 K
# [Steady-state check] step 119400, max |T - T_ext| = 2.107e-02 K
# [Steady-state check] step 119600, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 119800, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 120000, max |T - T_ext| = 2.108e-02 K
# Non-diurnal step 120000, time=101.28s
# [Steady-state check] step 120200, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 120400, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 120600, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 120800, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 121000, max |T - T_ext| = 2.108e-02 K
# Non-diurnal step 121000, time=102.13s
# [Steady-state check] step 121200, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 121400, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 121600, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 121800, max |T - T_ext| = 2.108e-02 K
# [Steady-state check] step 122000, max |T - T_ext| = 2.109e-02 K
# Non-diurnal step 122000, time=102.97s
# [Steady-state check] step 122200, max |T - T_ext| = 2.109e-02 K
# [Steady-state check] step 122400, max |T - T_ext| = 2.109e-02 K
# [Steady-state check] step 122600, max |T - T_ext| = 2.109e-02 K
# [Steady-state check] step 122800, max |T - T_ext| = 2.109e-02 K
# [Steady-state check] step 123000, max |T - T_ext| = 2.109e-02 K
# Non-diurnal step 123000, time=103.82s
# [Steady-state check] step 123200, max |T - T_ext| = 2.109e-02 K
# [Steady-state check] step 123400, max |T - T_ext| = 2.109e-02 K
# [Steady-state check] step 123600, max |T - T_ext| = 1.934e-02 K
# Converged to steady-state (all |T - T_ext| < 0.02) at step 123600, t=104.32s.
# Computing DISORT radiance spectra for output.
# Computing DISORT emissivity spectra for output.
# Radiance calculation completed.
# Simulation completed in 28.10 s
# Simulation completed! Output shape: (114, 1)
# Time range: 0 to 0 seconds
# Surface temperature range: 500.0 to 500.0 K

# %% [markdown]
# ## Plot vacuum thermal gradient

# %%
plt.plot(T_out2[1:,-1]-sim2.cfg.T_bottom ,sim2.grid.x[1:]/sim2.cfg.Et * 1e6)
plt.ylabel('Depth into medium [µm]')
plt.xlabel('Temperature Difference [K]')
plt.ylim([0,1000])
#plt.legend(loc='upper right')
plt.grid(True)
plt.gca().invert_yaxis()
plt.show()

plt.semilogy(T_out2[1:,-1]-sim2.cfg.T_bottom ,sim2.grid.x[1:]/sim2.cfg.Et)
plt.ylabel('Depth into medium [m]')
plt.xlabel('Temperature Difference [K]')
#plt.legend(loc='upper right')
plt.grid(True)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Plot vacuum spectrum

# %%
# Plot vacuum spectrum comparison using new framework
print("Computing vacuum radiance using new framework...")
radiance_results2 = calculate_radiances_from_results(sim2)

# Extract vacuum results
final_rad2 = radiance_results2['radiance_thermal'][:, -1]  # [wavelengths] for single observer
T_fit2, B_fit2, btemps2, wn_BB2 = max_btemp_blackbody(sim2, wn_bounds, final_rad2)
emiss_spec2 = final_rad2 / B_fit2

# Normalize vacuum emissivity
idx1 = np.argmin(np.abs(wn - 900))
idx2 = np.argmin(np.abs(wn - 1700))
ds_cf_emis2 = emiss_spec2[idx1:idx2+1].max()

# Create comparison plots
plt.figure(figsize=(14, 6))

# Plot 1: Wavenumber space
plt.subplot(1, 2, 1)
plt.plot(wn[:ir_cutoff], emiss_spec[:ir_cutoff] + 1 - ds_cf_emis, 
         label=f'Isothermal (T_fit={T_fit:.1f}K)', linewidth=2)
plt.plot(wn[:ir_cutoff], emiss_spec2[:ir_cutoff] + 1 - ds_cf_emis2, 
         label=f'Vacuum (T_fit={T_fit2:.1f}K)', linewidth=2)
plt.xlabel('Wavenumber [cm$^{-1}$]')
plt.ylabel('Normalized Emissivity')
plt.title('Emissivity Comparison\\n(Wavenumber Space)')
plt.legend()
plt.grid(True)
plt.gca().invert_xaxis()

# Plot 2: Wavelength space
plt.subplot(1, 2, 2)
plt.plot(10000./wn[:ir_cutoff], emiss_spec[:ir_cutoff] + 1 - ds_cf_emis, 
         label=f'Isothermal (T_fit={T_fit:.1f}K)', linewidth=2)
plt.plot(10000./wn[:ir_cutoff], emiss_spec2[:ir_cutoff] + 1 - ds_cf_emis2, 
         label=f'Vacuum (T_fit={T_fit2:.1f}K)', linewidth=2)
plt.xlabel('Wavelength [µm]')
plt.ylabel('Normalized Emissivity')
plt.title('Emissivity Comparison\\n(Wavelength Space)')
plt.xlim([6, 14])
plt.legend()
plt.grid(True)

plt.suptitle('Millan et al. 2011 Reproduction: Isothermal vs Vacuum Thermal Gradient Effects', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# Quantitative comparison
print(f"\\n=== QUANTITATIVE COMPARISON ===")
print(f"Isothermal case:")
print(f"  • Brightness temperature: {T_fit:.1f} K")
print(f"  • Peak emissivity: {emiss_spec.max():.3f}")
print(f"  • Radiance processing: {radiance_results1['spectral_mode']} mode")

print(f"\\nVacuum case:")
print(f"  • Brightness temperature: {T_fit2:.1f} K") 
print(f"  • Peak emissivity: {emiss_spec2.max():.3f}")
print(f"  • Radiance processing: {radiance_results2['spectral_mode']} mode")

# Calculate difference
temp_diff = T_fit2 - T_fit
emiss_diff = np.abs(emiss_spec2 - emiss_spec).max()
print(f"\\nDifferences:")
print(f"  • Temperature difference: {temp_diff:.1f} K")
print(f"  • Max emissivity difference: {emiss_diff:.4f}")

print(f"\\n✓ Vacuum radiance computed using new framework")
print(f"✓ Both simulations processed consistently")
print(f"✓ Easy comparison enabled by unified interface")
